# %%
from bs4 import BeautifulSoup
import requests

response = requests.get("https://www.udacity.com/courses/all")
html_soup = BeautifulSoup(response.content, 'html.parser')

#find all the URLs (items in the html where href exists)
url = html_soup.find_all(href=True)

#Iterate through the urls, and only return the ones that contain course and --
links = []
for u in url:
    if (u['href'].find('course') != -1):
        if (u['href'].find('--') != -1):
            if (u['href'].find('nanodegree') == -1):
                links.append(u['href'])
            
#remove duplicates by converting the list of links to a set, then back to a list
links = list(set(links))
print(len(links)) 
links
# Out:
# 211
# ['/course/web-tooling-automation--ud892',
#  '/course/intro-to-machine-learning--ud120',
#  '/course/real-time-analytics-with-apache-storm--ud381',
#  '/course/intro-to-html-and-css--ud001',
#  '/course/get-your-startup-started--ud806',
#  '/course/swift-for-beginners--ud1022',
#  '/course/intro-to-algorithms--cs215',
#  'https://www.udacity.com/course/activation-and-retention-strategy--nd037-2',
#  'https://www.udacity.com/course/data-science-for-business-leaders--nd045',
#  '/course/intro-to-progressive-web-apps--ud811',
#  '/course/server-side-swift--ud1031',
#  '/course/java-programming-basics--ud282',
#  '/course/responsive-images--ud882',
#  '/course/data-science-for-business-leaders--nd045',
#  '/course/data-wrangling-with-mongodb--ud032',
#  '/course/data-analysis-with-r--ud651',
#  '/course/advanced-operating-systems--ud189',
#  '/course/learn-spark-at-udacity--ud2002',
#  '/course/model-building-and-validation--ud919',
#  '/course/mobile-design-and-usability-for-android--ud358',
#  '/course/linear-algebra-refresher-course--ud953',
#  'https://www.udacity.com/course/robotics-software-engineer--nd209',
#  '/course/intro-to-devops--ud611',
#  '/course/intro-to-statistics--st101',
#  '/course/hybrid-cloud-fundamentals--ud0321',
#  '/course/high-performance-computing--ud281',
#  '/courses/data-science-for-business-leaders--nd045',
#  '/course/segmentation-and-clustering--ud981',
#  '/course/wechat-mini-programs--ud667',
#  '/course/data-structures-and-algorithms-in-swift--ud1011',
#  '/course/introduction-to-graduate-algorithms--ud401',
#  '/course/interactive-3d-graphics--cs291',
#  '/course/javascript-design-patterns--ud989',
#  '/course/ab-testing--ud257',
#  '/course/intro-to-tensorflow-for-deep-learning--ud187',
#  '/course/intro-to-point-click-app-development--ud162',
#  '/courses/learn-sql--nd072',
#  '/course/software-analysis-testing--ud333',
#  '/course/craft-your-cover-letter--ud244',
#  '/course/android-basics-networking--ud843',
#  '/course/auto-layout--ud1026',
#  '/course/artificial-intelligence--ud954',
#  '/course/intro-to-jquery--ud245',
#  '/course/applied-cryptography--cs387',
#  '/course/machine-learning-for-trading--ud501',
#  '/course/product-design--ud509',
#  '/course/software-development-process--ud805',
#  '/course/networking-for-web-developers--ud256',
#  '/course/app-monetization--ud518',
#  '/course/vr-interview-prep--ud251',
#  '/course/xcode-debugging--ud774',
#  '/course/machine-learning-interview-prep--ud1001',
#  '/course/embedded-systems--ud169',
#  '/course/gradle-for-android-and-java--ud867',
#  '/course/firebase-analytics-android--ud354',
#  '/course/shell-workshop--ud206',
#  '/course/ab-testing--ud979',
#  '/course/offline-web-applications--ud899',
#  '/course/computer-networking--ud436',
#  '/course/high-performance-computer-architecture--ud007',
#  '/course/big-data-analytics-in-healthcare--ud758',
#  '/course/ux-design-for-mobile-developers--ud849',
#  '/course/intro-to-ios-app-development-with-swift--ud585',
#  '/courses/ai-for-business-leaders--nd054',
#  '/course/passwordless-login-solutions-for-ios--ud1028',
#  '/course/build-native-mobile-apps-with-flutter--ud905',
#  '/course/aws-deepracer--ud014',
#  '/course/android-basics-user-input--ud836',
#  '/course/es6-javascript-improved--ud356',
#  'https://www.udacity.com/course/learn-sql--nd072',
#  '/course/front-end-frameworks--ud894',
#  '/course/http-web-servers--ud303',
#  '/course/introduction-to-operating-systems--ud923',
#  '/course/developing-android-apps-with-kotlin--ud9012',
#  '/course/deploying-a-hadoop-cluster--ud1000',
#  '/course/strengthen-your-linkedin-network-and-brand--ud242',
#  '/course/passwordless-login-solutions-for-android--ud357',
#  '/course/authentication-authorization-oauth--ud330',
#  '/course/data-visualization-in-tableau--ud1006',
#  '/course/uikit-fundamentals--ud788',
#  '/course/intel-edge-AI-fundamentals-with-openvino--ud132',
#  '/course/introduction-to-computer-vision--ud810',
#  '/courses/intro-to-self-driving-cars--nd113',
#  '/course/design-of-computer-programs--cs212',
#  '/course/localization-essentials--ud610',
#  '/course/core-ml--ud1038',
#  '/course/managing-remote-teams-with-upwork--ud942',
#  '/course/android-performance--ud825',
#  '/course/version-control-with-git--ud123',
#  '/course/firebase-analytics-ios--ud353',
#  '/course/learn-sql--nd072',
#  '/course/software-testing--cs258',
#  '/course/ios-networking-with-swift--ud421',
#  '/course/android-interview-prep--ud241',
#  '/course/full-stack-interview-prep--ud252',
#  '/course/new-android-fundamentals--ud851',
#  '/course/deep-learning-pytorch--ud188',
#  '/course/software-debugging--cs259',
#  '/course/sql-for-data-analysis--ud198',
#  '/course/learn-swift-programming-syntax--ud902',
#  '/course/intro-to-descriptive-statistics--ud827',
#  '/course/intro-to-tensorflow-lite--ud190',
#  '/courses/robotics-software-engineer--nd209',
#  '/course/introduction-to-python--ud1110',
#  '/course/statistics--st095',
#  '/course/monetization-strategy--nd037-3',
#  '/course/objective-c-for-swift-developers--ud1009',
#  '/course/advanced-android-with-kotlin--ud940',
#  '/course/android-basics-user-interface--ud834',
#  '/course/firebase-in-a-weekend-by-google-android--ud0352',
#  '/course/artificial-intelligence-for-robotics--cs373',
#  '/course/ios-interview-prep--ud240',
#  '/course/network-security--ud199',
#  '/course/intro-to-cloud-computing--ud080',
#  '/course/intro-to-data-science--ud359',
#  '/course/problem-solving-with-advanced-analytics--ud976',
#  '/course/cyber-physical-systems-design-analysis--ud9876',
#  '/course/the-mvc-pattern-in-ruby--ud270',
#  '/course/secure-and-private-ai--ud185',
#  '/course/robotics-software-engineer--nd209',
#  '/course/what-is-programming--ud994',
#  '/course/scalable-microservices-with-kubernetes--ud615',
#  '/course/2d-game-development-with-libgdx--ud405',
#  '/course/intro-to-relational-databases--ud197',
#  '/course/app-marketing--ud719',
#  'https://www.udacity.com/course/ai-for-business-leaders--nd054',
#  '/course/how-to-install-android-studio--ud808',
#  '/course/compilers-theory-and-practice--ud168',
#  '/course/computability-complexity-algorithms--ud061',
#  '/course/product-manager-interview-preparation--ud034',
#  '/course/microsoft-power-platform--ud091',
#  '/course/deploying-applications-with-heroku--ud272',
#  '/course/grand-central-dispatch-gcd--ud576',
#  '/course/database-systems-concepts-design--ud150',
#  '/course/mobile-design-and-usability-for-ios--ud1034',
#  '/course/firebase-in-a-weekend-by-google-ios--ud0351',
#  '/course/browser-rendering-optimization--ud860',
#  '/course/linux-command-line-basics--ud595',
#  '/course/kotlin-for-android-developers--ud888',
#  '/course/intro-to-physics--ph100',
#  '/course/refresh-your-resume--ud243',
#  '/course/engagement-monetization-mobile-games--ud407',
#  '/course/javascript-testing--ud549',
#  '/course/front-end-interview-prep--ud250',
#  '/course/javascript-promises--ud898',
#  '/course/intro-to-inferential-statistics--ud201',
#  '/course/kotlin-bootcamp-for-programmers--ud9011',
#  '/courses/ai-for-trading--nd880',
#  '/course/material-design-for-android-developers--ud862',
#  '/course/intro-to-data-analysis--ud170',
#  '/course/programming-languages--cs262',
#  '/course/how-to-make-a-platformer-using-libgdx--ud406',
#  '/course/android-basics-data-storage--ud845',
#  '/course/dynamic-web-applications-with-sinatra--ud268',
#  '/course/intro-to-ajax--ud110',
#  '/course/javascript-and-the-dom--ud117',
#  '/course/website-performance-optimization--ud884',
#  '/course/creating-an-analytical-dataset--ud977',
#  '/course/data-visualization-and-d3js--ud507',
#  '/course/human-computer-interaction--ud400',
#  '/course/machine-learning-unsupervised-learning--ud741',
#  '/course/building-high-conversion-web-forms--ud890',
#  '/course/object-oriented-javascript--ud711',
#  '/course/asynchronous-javascript-requests--ud109',
#  '/course/classification-models--ud978',
#  '/courses/monetization-strategy--nd037-3',
#  '/course/how-to-make-an-ios-app--ud607',
#  '/course/data-science-interview-prep--ud944',
#  '/course/intro-to-self-driving-cars--nd113',
#  '/course/software-architecture-design--ud821',
#  '/course/cyber-physical-systems-security--ud279',
#  '/course/configuring-linux-web-servers--ud299',
#  'https://www.udacity.com/course/monetization-strategy--nd037-3',
#  '/course/differential-equations-in-action--cs222',
#  '/course/activation-and-retention-strategy--nd037-2',
#  '/course/reinforcement-learning--ud600',
#  '/course/writing-readmes--ud777',
#  '/course/intro-to-psychology--ps001',
#  '/course/data-analysis-and-visualization--ud404',
#  '/course/eigenvectors-and-eigenvalues--ud104',
#  '/course/ios-persistence-and-core-data--ud325',
#  '/course/ai-for-business-leaders--nd054',
#  '/course/self-driving-car-fundamentals-featuring-apollo--ud0419',
#  '/course/intro-to-artificial-intelligence--cs271',
#  'https://www.udacity.com/course/intro-to-self-driving-cars--nd113',
#  '/course/ai-for-trading--nd880',
#  '/course/swift-for-developers--ud1025',
#  '/course/machine-learning--ud262',
#  '/course/client-server-communication--ud897',
#  '/course/introduction-to-virtual-reality--ud1012',
#  '/course/how-to-build-a-startup--ep245',
#  '/course/intro-to-backend--ud171',
#  '/course/html5-canvas--ud292',
#  '/course/rapid-prototyping--ud723',
#  '/course/android-basics-multiscreen-apps--ud839',
#  '/course/object-oriented-programming-in-java--ud283',
#  '/course/gt-refresher-advanced-os--ud098',
#  '/courses/activation-and-retention-strategy--nd037-2',
#  '/course/responsive-web-design-fundamentals--ud893',
#  '/course/intro-to-hadoop-and-mapreduce--ud617',
#  '/course/advanced-android-app-development--ud855',
#  '/course/designing-restful-apis--ud388',
#  '/course/intro-to-theoretical-computer-science--cs313',
#  '/course/google-maps-apis--ud864',
#  '/course/intro-to-javascript--ud803',
#  '/course/intro-to-information-security--ud459',
#  '/course/time-series-forecasting--ud980',
#  '/course/knowledge-based-ai-cognitive-systems--ud409',
#  '/course/c-for-programmers--ud210',
#  '/course/web-accessibility--ud891',
#  '/course/full-stack-foundations--ud088']

# %%
import pandas as pd
from pandas import DataFrame
#convert to dataframe & replace "https://www.udacity.com"
df = DataFrame (links,columns=['url'])
df['url'] = df['url'].str.replace('https://www.udacity.com','')
#convert back to list
links = df['url'].tolist()

# %%
links
# Out:
# ['/course/web-tooling-automation--ud892',
#  '/course/intro-to-machine-learning--ud120',
#  '/course/real-time-analytics-with-apache-storm--ud381',
#  '/course/intro-to-html-and-css--ud001',
#  '/course/get-your-startup-started--ud806',
#  '/course/swift-for-beginners--ud1022',
#  '/course/intro-to-algorithms--cs215',
#  '/course/activation-and-retention-strategy--nd037-2',
#  '/course/data-science-for-business-leaders--nd045',
#  '/course/intro-to-progressive-web-apps--ud811',
#  '/course/server-side-swift--ud1031',
#  '/course/java-programming-basics--ud282',
#  '/course/responsive-images--ud882',
#  '/course/data-science-for-business-leaders--nd045',
#  '/course/data-wrangling-with-mongodb--ud032',
#  '/course/data-analysis-with-r--ud651',
#  '/course/advanced-operating-systems--ud189',
#  '/course/learn-spark-at-udacity--ud2002',
#  '/course/model-building-and-validation--ud919',
#  '/course/mobile-design-and-usability-for-android--ud358',
#  '/course/linear-algebra-refresher-course--ud953',
#  '/course/robotics-software-engineer--nd209',
#  '/course/intro-to-devops--ud611',
#  '/course/intro-to-statistics--st101',
#  '/course/hybrid-cloud-fundamentals--ud0321',
#  '/course/high-performance-computing--ud281',
#  '/courses/data-science-for-business-leaders--nd045',
#  '/course/segmentation-and-clustering--ud981',
#  '/course/wechat-mini-programs--ud667',
#  '/course/data-structures-and-algorithms-in-swift--ud1011',
#  '/course/introduction-to-graduate-algorithms--ud401',
#  '/course/interactive-3d-graphics--cs291',
#  '/course/javascript-design-patterns--ud989',
#  '/course/ab-testing--ud257',
#  '/course/intro-to-tensorflow-for-deep-learning--ud187',
#  '/course/intro-to-point-click-app-development--ud162',
#  '/courses/learn-sql--nd072',
#  '/course/software-analysis-testing--ud333',
#  '/course/craft-your-cover-letter--ud244',
#  '/course/android-basics-networking--ud843',
#  '/course/auto-layout--ud1026',
#  '/course/artificial-intelligence--ud954',
#  '/course/intro-to-jquery--ud245',
#  '/course/applied-cryptography--cs387',
#  '/course/machine-learning-for-trading--ud501',
#  '/course/product-design--ud509',
#  '/course/software-development-process--ud805',
#  '/course/networking-for-web-developers--ud256',
#  '/course/app-monetization--ud518',
#  '/course/vr-interview-prep--ud251',
#  '/course/xcode-debugging--ud774',
#  '/course/machine-learning-interview-prep--ud1001',
#  '/course/embedded-systems--ud169',
#  '/course/gradle-for-android-and-java--ud867',
#  '/course/firebase-analytics-android--ud354',
#  '/course/shell-workshop--ud206',
#  '/course/ab-testing--ud979',
#  '/course/offline-web-applications--ud899',
#  '/course/computer-networking--ud436',
#  '/course/high-performance-computer-architecture--ud007',
#  '/course/big-data-analytics-in-healthcare--ud758',
#  '/course/ux-design-for-mobile-developers--ud849',
#  '/course/intro-to-ios-app-development-with-swift--ud585',
#  '/courses/ai-for-business-leaders--nd054',
#  '/course/passwordless-login-solutions-for-ios--ud1028',
#  '/course/build-native-mobile-apps-with-flutter--ud905',
#  '/course/aws-deepracer--ud014',
#  '/course/android-basics-user-input--ud836',
#  '/course/es6-javascript-improved--ud356',
#  '/course/learn-sql--nd072',
#  '/course/front-end-frameworks--ud894',
#  '/course/http-web-servers--ud303',
#  '/course/introduction-to-operating-systems--ud923',
#  '/course/developing-android-apps-with-kotlin--ud9012',
#  '/course/deploying-a-hadoop-cluster--ud1000',
#  '/course/strengthen-your-linkedin-network-and-brand--ud242',
#  '/course/passwordless-login-solutions-for-android--ud357',
#  '/course/authentication-authorization-oauth--ud330',
#  '/course/data-visualization-in-tableau--ud1006',
#  '/course/uikit-fundamentals--ud788',
#  '/course/intel-edge-AI-fundamentals-with-openvino--ud132',
#  '/course/introduction-to-computer-vision--ud810',
#  '/courses/intro-to-self-driving-cars--nd113',
#  '/course/design-of-computer-programs--cs212',
#  '/course/localization-essentials--ud610',
#  '/course/core-ml--ud1038',
#  '/course/managing-remote-teams-with-upwork--ud942',
#  '/course/android-performance--ud825',
#  '/course/version-control-with-git--ud123',
#  '/course/firebase-analytics-ios--ud353',
#  '/course/learn-sql--nd072',
#  '/course/software-testing--cs258',
#  '/course/ios-networking-with-swift--ud421',
#  '/course/android-interview-prep--ud241',
#  '/course/full-stack-interview-prep--ud252',
#  '/course/new-android-fundamentals--ud851',
#  '/course/deep-learning-pytorch--ud188',
#  '/course/software-debugging--cs259',
#  '/course/sql-for-data-analysis--ud198',
#  '/course/learn-swift-programming-syntax--ud902',
#  '/course/intro-to-descriptive-statistics--ud827',
#  '/course/intro-to-tensorflow-lite--ud190',
#  '/courses/robotics-software-engineer--nd209',
#  '/course/introduction-to-python--ud1110',
#  '/course/statistics--st095',
#  '/course/monetization-strategy--nd037-3',
#  '/course/objective-c-for-swift-developers--ud1009',
#  '/course/advanced-android-with-kotlin--ud940',
#  '/course/android-basics-user-interface--ud834',
#  '/course/firebase-in-a-weekend-by-google-android--ud0352',
#  '/course/artificial-intelligence-for-robotics--cs373',
#  '/course/ios-interview-prep--ud240',
#  '/course/network-security--ud199',
#  '/course/intro-to-cloud-computing--ud080',
#  '/course/intro-to-data-science--ud359',
#  '/course/problem-solving-with-advanced-analytics--ud976',
#  '/course/cyber-physical-systems-design-analysis--ud9876',
#  '/course/the-mvc-pattern-in-ruby--ud270',
#  '/course/secure-and-private-ai--ud185',
#  '/course/robotics-software-engineer--nd209',
#  '/course/what-is-programming--ud994',
#  '/course/scalable-microservices-with-kubernetes--ud615',
#  '/course/2d-game-development-with-libgdx--ud405',
#  '/course/intro-to-relational-databases--ud197',
#  '/course/app-marketing--ud719',
#  '/course/ai-for-business-leaders--nd054',
#  '/course/how-to-install-android-studio--ud808',
#  '/course/compilers-theory-and-practice--ud168',
#  '/course/computability-complexity-algorithms--ud061',
#  '/course/product-manager-interview-preparation--ud034',
#  '/course/microsoft-power-platform--ud091',
#  '/course/deploying-applications-with-heroku--ud272',
#  '/course/grand-central-dispatch-gcd--ud576',
#  '/course/database-systems-concepts-design--ud150',
#  '/course/mobile-design-and-usability-for-ios--ud1034',
#  '/course/firebase-in-a-weekend-by-google-ios--ud0351',
#  '/course/browser-rendering-optimization--ud860',
#  '/course/linux-command-line-basics--ud595',
#  '/course/kotlin-for-android-developers--ud888',
#  '/course/intro-to-physics--ph100',
#  '/course/refresh-your-resume--ud243',
#  '/course/engagement-monetization-mobile-games--ud407',
#  '/course/javascript-testing--ud549',
#  '/course/front-end-interview-prep--ud250',
#  '/course/javascript-promises--ud898',
#  '/course/intro-to-inferential-statistics--ud201',
#  '/course/kotlin-bootcamp-for-programmers--ud9011',
#  '/courses/ai-for-trading--nd880',
#  '/course/material-design-for-android-developers--ud862',
#  '/course/intro-to-data-analysis--ud170',
#  '/course/programming-languages--cs262',
#  '/course/how-to-make-a-platformer-using-libgdx--ud406',
#  '/course/android-basics-data-storage--ud845',
#  '/course/dynamic-web-applications-with-sinatra--ud268',
#  '/course/intro-to-ajax--ud110',
#  '/course/javascript-and-the-dom--ud117',
#  '/course/website-performance-optimization--ud884',
#  '/course/creating-an-analytical-dataset--ud977',
#  '/course/data-visualization-and-d3js--ud507',
#  '/course/human-computer-interaction--ud400',
#  '/course/machine-learning-unsupervised-learning--ud741',
#  '/course/building-high-conversion-web-forms--ud890',
#  '/course/object-oriented-javascript--ud711',
#  '/course/asynchronous-javascript-requests--ud109',
#  '/course/classification-models--ud978',
#  '/courses/monetization-strategy--nd037-3',
#  '/course/how-to-make-an-ios-app--ud607',
#  '/course/data-science-interview-prep--ud944',
#  '/course/intro-to-self-driving-cars--nd113',
#  '/course/software-architecture-design--ud821',
#  '/course/cyber-physical-systems-security--ud279',
#  '/course/configuring-linux-web-servers--ud299',
#  '/course/monetization-strategy--nd037-3',
#  '/course/differential-equations-in-action--cs222',
#  '/course/activation-and-retention-strategy--nd037-2',
#  '/course/reinforcement-learning--ud600',
#  '/course/writing-readmes--ud777',
#  '/course/intro-to-psychology--ps001',
#  '/course/data-analysis-and-visualization--ud404',
#  '/course/eigenvectors-and-eigenvalues--ud104',
#  '/course/ios-persistence-and-core-data--ud325',
#  '/course/ai-for-business-leaders--nd054',
#  '/course/self-driving-car-fundamentals-featuring-apollo--ud0419',
#  '/course/intro-to-artificial-intelligence--cs271',
#  '/course/intro-to-self-driving-cars--nd113',
#  '/course/ai-for-trading--nd880',
#  '/course/swift-for-developers--ud1025',
#  '/course/machine-learning--ud262',
#  '/course/client-server-communication--ud897',
#  '/course/introduction-to-virtual-reality--ud1012',
#  '/course/how-to-build-a-startup--ep245',
#  '/course/intro-to-backend--ud171',
#  '/course/html5-canvas--ud292',
#  '/course/rapid-prototyping--ud723',
#  '/course/android-basics-multiscreen-apps--ud839',
#  '/course/object-oriented-programming-in-java--ud283',
#  '/course/gt-refresher-advanced-os--ud098',
#  '/courses/activation-and-retention-strategy--nd037-2',
#  '/course/responsive-web-design-fundamentals--ud893',
#  '/course/intro-to-hadoop-and-mapreduce--ud617',
#  '/course/advanced-android-app-development--ud855',
#  '/course/designing-restful-apis--ud388',
#  '/course/intro-to-theoretical-computer-science--cs313',
#  '/course/google-maps-apis--ud864',
#  '/course/intro-to-javascript--ud803',
#  '/course/intro-to-information-security--ud459',
#  '/course/time-series-forecasting--ud980',
#  '/course/knowledge-based-ai-cognitive-systems--ud409',
#  '/course/c-for-programmers--ud210',
#  '/course/web-accessibility--ud891',
#  '/course/full-stack-foundations--ud088']

# %%
import time
from random import randint

#initilise the lists to store the extracted info
course_names = []
course_urls = []
course_nanodegrees = []
course_costs = []

# Preparing the monitoring of the loop
start_time = time.time()
requests_count = 0

#iterate through each link to extract info about the nano degree it belongs to and the cost
for i in range(len(links)):
    #need to make requests at random times in order to not be blocked by website
    time.sleep(randint (2,2)) 
    url = "https://www.udacity.com" + links[i]
    response = requests.get(url)
    content = response.content
    html_soup = BeautifulSoup(content, 'html.parser')
    
    # Monitor the requests
    requests_count += 1
    elapsed_time = time.time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests_count, requests_count/elapsed_time))
    #clear_output(wait = True)
    
    # Break the loop if the number of requests is greater than expected
    if requests_count > 250:
        warn('Number of requests was greater than expected.')  
        break 
    
    try:
        nanodegree = html_soup.find('h3',class_="h1 hero__nanodegree--title").text
    except:
        nanodegree = 'None'
    try:
        course_name = html_soup.find('h1',class_='hero__course--title').text
    except:
        course_name = 'None'
    try:
        cost = html_soup.find('h6',class_='hero__course--type').text
    except:
        cost = 'None'
    course_names.append(course_name)
    course_urls.append(url)
    course_nanodegrees.append(nanodegree)
    course_costs.append(cost)
# Out:
# Request:1; Frequency: 0.428317867250079 requests/s
# Request:2; Frequency: 0.4154409414116708 requests/s
# Request:3; Frequency: 0.4193502761405721 requests/s
# Request:4; Frequency: 0.41149851914438057 requests/s
# Request:5; Frequency: 0.4019318699921112 requests/s
# Request:6; Frequency: 0.406138502170224 requests/s
# Request:7; Frequency: 0.4029732267182822 requests/s
# Request:8; Frequency: 0.3978893801840999 requests/s
# Request:9; Frequency: 0.3964341783282604 requests/s
# Request:10; Frequency: 0.4002640902597478 requests/s
# Request:11; Frequency: 0.40333314677882875 requests/s
# Request:12; Frequency: 0.4026386600182558 requests/s
# Request:13; Frequency: 0.40247091049730993 requests/s
# Request:14; Frequency: 0.3956723978359725 requests/s
# Request:15; Frequency: 0.39793475509355936 requests/s
# Request:16; Frequency: 0.40011639881776034 requests/s
# Request:17; Frequency: 0.40196327957427025 requests/s
# Request:18; Frequency: 0.40313168303245656 requests/s
# Request:19; Frequency: 0.4046567422712018 requests/s
# Request:20; Frequency: 0.40562769471966387 requests/s
# Request:21; Frequency: 0.4068259724272682 requests/s
# Request:22; Frequency: 0.40580088198343844 requests/s
# Request:23; Frequency: 0.4051357964116882 requests/s
# Request:24; Frequency: 0.40449093679649495 requests/s
# Request:25; Frequency: 0.40544437099544195 requests/s
# Request:26; Frequency: 0.40610551572898707 requests/s
# Request:27; Frequency: 0.4058970162602628 requests/s
# Request:28; Frequency: 0.40605637355911556 requests/s
# Request:29; Frequency: 0.4070488008060151 requests/s
# Request:30; Frequency: 0.4078110859605503 requests/s
# Request:31; Frequency: 0.40876678099144687 requests/s
# Request:32; Frequency: 0.40953596001406517 requests/s
# Request:33; Frequency: 0.41035247072823966 requests/s
# Request:34; Frequency: 0.4106683794559283 requests/s
# Request:35; Frequency: 0.41132341757566315 requests/s
# Request:36; Frequency: 0.41180048623811466 requests/s
# Request:37; Frequency: 0.41104914895766803 requests/s
# Request:38; Frequency: 0.41158243175707737 requests/s
# Request:39; Frequency: 0.41223390066975785 requests/s
# Request:40; Frequency: 0.4125785938331004 requests/s
# Request:41; Frequency: 0.41313535284109837 requests/s
# Request:42; Frequency: 0.4134407819997399 requests/s
# Request:43; Frequency: 0.4137937097838125 requests/s
# Request:44; Frequency: 0.41403101030288525 requests/s
# Request:45; Frequency: 0.4141204264171542 requests/s
# Request:46; Frequency: 0.4135407136008287 requests/s
# Request:47; Frequency: 0.4139183801524432 requests/s
# Request:48; Frequency: 0.4143599856253982 requests/s
# Request:49; Frequency: 0.4147276642087272 requests/s
# Request:50; Frequency: 0.4146305119749632 requests/s
# Request:51; Frequency: 0.4149004437375481 requests/s
# Request:52; Frequency: 0.41453791747195173 requests/s
# Request:53; Frequency: 0.4146762974260803 requests/s
# Request:54; Frequency: 0.4146632401850058 requests/s
# Request:55; Frequency: 0.4148599632143517 requests/s
# Request:56; Frequency: 0.4151929606617185 requests/s
# Request:57; Frequency: 0.41559086897310954 requests/s
# Request:58; Frequency: 0.4152455085131296 requests/s
# Request:59; Frequency: 0.41541190309814846 requests/s
# Request:60; Frequency: 0.4151068449703846 requests/s
# Request:61; Frequency: 0.415261994651628 requests/s
# Request:62; Frequency: 0.41540642960750174 requests/s
# Request:63; Frequency: 0.41522801305286133 requests/s
# Request:64; Frequency: 0.4141036591077257 requests/s
# Request:65; Frequency: 0.41429947689656776 requests/s
# Request:66; Frequency: 0.4139513821553284 requests/s
# Request:67; Frequency: 0.4141549993208965 requests/s
# Request:68; Frequency: 0.41436339259639493 requests/s
# Request:69; Frequency: 0.41465750937738105 requests/s
# Request:70; Frequency: 0.41430556913637456 requests/s
# Request:71; Frequency: 0.4142892726035778 requests/s
# Request:72; Frequency: 0.4141751029656982 requests/s
# Request:73; Frequency: 0.41429055810539017 requests/s
# Request:74; Frequency: 0.41422103479885 requests/s
# Request:75; Frequency: 0.4143456643663001 requests/s
# Request:76; Frequency: 0.4146168500335894 requests/s
# Request:77; Frequency: 0.41443716416472837 requests/s
# Request:78; Frequency: 0.4147201999104329 requests/s
# Request:79; Frequency: 0.4148729684511541 requests/s
# Request:80; Frequency: 0.4150863557711703 requests/s
# Request:81; Frequency: 0.4152945416467296 requests/s
# Request:82; Frequency: 0.41517032764820155 requests/s
# Request:83; Frequency: 0.41447243627386215 requests/s
# Request:84; Frequency: 0.41470023970786424 requests/s
# Request:85; Frequency: 0.41406396153583835 requests/s
# Request:86; Frequency: 0.414292812162931 requests/s
# Request:87; Frequency: 0.41452153638565997 requests/s
# Request:88; Frequency: 0.4146299468739739 requests/s
# Request:89; Frequency: 0.4149321563911879 requests/s
# Request:90; Frequency: 0.415173287837704 requests/s
# Request:91; Frequency: 0.41482213317315497 requests/s
# Request:92; Frequency: 0.4149911905186647 requests/s
# Request:93; Frequency: 0.4151868586020378 requests/s
# Request:94; Frequency: 0.4154324241928657 requests/s
# Request:95; Frequency: 0.41560549729985263 requests/s
# Request:96; Frequency: 0.41518248291510523 requests/s
# Request:97; Frequency: 0.4152925809928757 requests/s
# Request:98; Frequency: 0.41546354054868473 requests/s
# Request:99; Frequency: 0.4151697942142036 requests/s
# Request:100; Frequency: 0.4153262699825868 requests/s
# Request:101; Frequency: 0.4154492575350471 requests/s
# Request:102; Frequency: 0.4156464694560956 requests/s
# Request:103; Frequency: 0.4155115260365138 requests/s
# Request:104; Frequency: 0.4153711198312236 requests/s
# Request:105; Frequency: 0.4155363887139148 requests/s
# Request:106; Frequency: 0.4152655335076785 requests/s
# Request:107; Frequency: 0.41540861489494463 requests/s
# Request:108; Frequency: 0.41545674549298806 requests/s
# Request:109; Frequency: 0.4150522800451396 requests/s
# Request:110; Frequency: 0.4149125224032611 requests/s
# Request:111; Frequency: 0.4146985180519834 requests/s
# Request:112; Frequency: 0.4145886885591339 requests/s
# Request:113; Frequency: 0.4144765197825846 requests/s
# Request:114; Frequency: 0.4147203237870949 requests/s
# Request:115; Frequency: 0.41487508063366585 requests/s
# Request:116; Frequency: 0.41501061813019813 requests/s
# Request:117; Frequency: 0.4151875020395738 requests/s
# Request:118; Frequency: 0.4153479757217344 requests/s
# Request:119; Frequency: 0.4154641619514329 requests/s
# Request:120; Frequency: 0.4148137049449585 requests/s
# Request:121; Frequency: 0.4148933871975751 requests/s
# Request:122; Frequency: 0.41501290130648993 requests/s
# Request:123; Frequency: 0.41511670363687997 requests/s
# Request:124; Frequency: 0.41520657384155224 requests/s
# Request:125; Frequency: 0.4150443619272649 requests/s
# Request:126; Frequency: 0.41484499741177117 requests/s
# Request:127; Frequency: 0.41500585720752026 requests/s
# Request:128; Frequency: 0.41515803974978793 requests/s
# Request:129; Frequency: 0.41525208555195087 requests/s
# Request:130; Frequency: 0.4153887103457958 requests/s
# Request:131; Frequency: 0.41554840422321326 requests/s
# Request:132; Frequency: 0.41571261968526174 requests/s
# Request:133; Frequency: 0.4158469123964667 requests/s
# Request:134; Frequency: 0.4159777459050935 requests/s
# Request:135; Frequency: 0.4161165070109447 requests/s
# Request:136; Frequency: 0.41617968930013405 requests/s
# Request:137; Frequency: 0.41632303747689 requests/s
# Request:138; Frequency: 0.4164914333313886 requests/s
# Request:139; Frequency: 0.4165342103658206 requests/s
# Request:140; Frequency: 0.4166573971088645 requests/s
# Request:141; Frequency: 0.4167063418796248 requests/s
# Request:142; Frequency: 0.4165937888349981 requests/s
# Request:143; Frequency: 0.4167527912937474 requests/s
# Request:144; Frequency: 0.41690664635171776 requests/s
# Request:145; Frequency: 0.41694320353212316 requests/s
# Request:146; Frequency: 0.41701901496638527 requests/s
# Request:147; Frequency: 0.4168660248273588 requests/s
# Request:148; Frequency: 0.41659963307888037 requests/s
# Request:149; Frequency: 0.4167225819704488 requests/s
# Request:150; Frequency: 0.4166216565011585 requests/s
# Request:151; Frequency: 0.4166392706163703 requests/s
# Request:152; Frequency: 0.4166808513557445 requests/s
# Request:153; Frequency: 0.4167646856318334 requests/s
# Request:154; Frequency: 0.41686351284191625 requests/s
# Request:155; Frequency: 0.4168973569420277 requests/s
# Request:156; Frequency: 0.41698713392124304 requests/s
# Request:157; Frequency: 0.4170219434208256 requests/s
# Request:158; Frequency: 0.4171394947122004 requests/s
# Request:159; Frequency: 0.4170425038021292 requests/s
# Request:160; Frequency: 0.41712995981706213 requests/s
# Request:161; Frequency: 0.4171385240980004 requests/s
# Request:162; Frequency: 0.417238749672766 requests/s
# Request:163; Frequency: 0.4173704693289047 requests/s
# Request:164; Frequency: 0.4174835345233588 requests/s
# Request:165; Frequency: 0.4175138318543216 requests/s
# Request:166; Frequency: 0.4173148817872776 requests/s
# Request:167; Frequency: 0.4173878324136442 requests/s
# Request:168; Frequency: 0.4174522928678723 requests/s
# Request:169; Frequency: 0.4173121219405182 requests/s
# Request:170; Frequency: 0.41745590111734604 requests/s
# Request:171; Frequency: 0.4174257691328347 requests/s
# Request:172; Frequency: 0.4172869191285994 requests/s
# Request:173; Frequency: 0.41713948801589856 requests/s
# Request:174; Frequency: 0.4172409022280535 requests/s
# Request:175; Frequency: 0.41702779871381085 requests/s
# Request:176; Frequency: 0.41713848945222604 requests/s
# Request:177; Frequency: 0.41723081430630515 requests/s
# Request:178; Frequency: 0.4171393108452037 requests/s
# Request:179; Frequency: 0.4172105346229565 requests/s
# Request:180; Frequency: 0.4173298543397017 requests/s
# Request:181; Frequency: 0.4173960295088008 requests/s
# Request:182; Frequency: 0.41722731825932774 requests/s
# Request:183; Frequency: 0.4173265771361455 requests/s
# Request:184; Frequency: 0.41722727536271426 requests/s
# Request:185; Frequency: 0.41700415217982456 requests/s
# Request:186; Frequency: 0.41668868189206437 requests/s
# Request:187; Frequency: 0.4167657818977169 requests/s
# Request:188; Frequency: 0.4166919607214859 requests/s
# Request:189; Frequency: 0.41658899064780713 requests/s
# Request:190; Frequency: 0.4166184005566977 requests/s
# Request:191; Frequency: 0.4166696466168198 requests/s
# Request:192; Frequency: 0.41670557569663724 requests/s
# Request:193; Frequency: 0.41676135469062214 requests/s
# Request:194; Frequency: 0.4167397908586769 requests/s
# Request:195; Frequency: 0.4168046393550156 requests/s
# Request:196; Frequency: 0.4168289695503648 requests/s
# Request:197; Frequency: 0.4168773104578874 requests/s
# Request:198; Frequency: 0.4164564420602772 requests/s
# Request:199; Frequency: 0.4165639325223685 requests/s
# Request:200; Frequency: 0.41663099075374455 requests/s
# Request:201; Frequency: 0.41672250791082255 requests/s
# Request:202; Frequency: 0.41685337754466206 requests/s
# Request:203; Frequency: 0.4167298868691162 requests/s
# Request:204; Frequency: 0.4166653320593148 requests/s
# Request:205; Frequency: 0.41646986565421584 requests/s
# Request:206; Frequency: 0.41652219130927376 requests/s
# Request:207; Frequency: 0.41660459178353276 requests/s
# Request:208; Frequency: 0.41671668664320344 requests/s
# Request:209; Frequency: 0.41677270823989904 requests/s
# Request:210; Frequency: 0.41683724044167414 requests/s
# Request:211; Frequency: 0.41695330059718844 requests/s

# %%
#Convert the lists to a dataframe
import pandas as pd
courses_df = pd.DataFrame({'Name': course_names,
                          'URL': course_urls,
                          'Nanodegree': course_nanodegrees,
                          'Cost':course_costs})
courses_df = courses_df.sort_values('Nanodegree')
print(courses_df.info())
courses_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211 entries, 0 to 210
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        211 non-null    object
#  1   URL         211 non-null    object
#  2   Nanodegree  211 non-null    object
#  3   Cost        211 non-null    object
# dtypes: object(4)
# memory usage: 8.2+ KB
# None
#                                          Name  \
# 0                    Web Tooling & Automation
# 134       Mobile Design and Usability for iOS
# 135                Firebase in a Weekend: iOS
# 136            Browser Rendering Optimization
# 137                 Linux Command Line Basics
# ..                                        ...
# 74                 Deploying a Hadoop Cluster
# 75   Strengthen Your LinkedIn Network & Brand
# 76   Passwordless Login Solutions for Android
# 52                           Embedded Systems
# 210                    Full Stack Foundations
#
#                                                    URL Nanodegree         Cost
# 0    https://www.udacity.com/course/web-tooling-aut...       None  Free Course
# 134  https://www.udacity.com/course/mobile-design-a...       None  Free Course
# 135  https://www.udacity.com/course/firebase-in-a-w...       None  Free Course
# 136  https://www.udacity.com/course/browser-renderi...       None  Free Course
# 137  https://www.udacity.com/course/linux-command-l...       None  Free Course
# ..                                                 ...        ...          ...
# 74   https://www.udacity.com/course/deploying-a-had...       None  Free Course
# 75   https://www.udacity.com/course/strengthen-your...       None  Free Course
# 76   https://www.udacity.com/course/passwordless-lo...       None  Free Course
# 52   https://www.udacity.com/course/embedded-system...       None  Free Course
# 210  https://www.udacity.com/course/full-stack-foun...       None  Free Course
#
# [211 rows x 4 columns]

# %%
courses_df.to_csv('free_courses.csv', encoding='utf-8')

# %%
print(len(links))
# Out:
# 211
